# %% [markdown]
# ### Install Python Libraries

# %%
! pip install langchain
! pip install langchain-core
! pip install langchain-community
! pip install google-generativeai
! pip install gephistreamer
# Out:
# Requirement already satisfied: langchain in c:\users\ericc\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.4 in c:\users\ericc\anaconda3\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\ericc\anaconda3\lib\site-packages (from langchain) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ericc\anaconda3\lib\site-packages (from langchain) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ericc\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (8.2.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (4.15.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\ericc\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\ericc\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\ericc\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\ericc\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ericc\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.4->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\ericc\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\ericc\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\ericc\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ericc\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ericc\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ericc\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\ericc\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\ericc\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ericc\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ericc\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ericc\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: langchain-core in c:\users\ericc\anaconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ericc\appdata\roaming\python\python312\site-packages (from langchain-core) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core) (8.2.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ericc\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: anyio in c:\users\ericc\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ericc\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ericc\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\ericc\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\ericc\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ericc\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ericc\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ericc\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: langchain-community in c:\users\ericc\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (1.0.4)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (8.2.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (0.4.42)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ericc\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ericc\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ericc\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ericc\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ericc\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ericc\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ericc\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ericc\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ericc\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ericc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ericc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ericc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ericc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ericc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.10.5)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ericc\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\ericc\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ericc\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ericc\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ericc\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ericc\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ericc\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: google-generativeai in c:\users\ericc\anaconda3\lib\site-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\ericc\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\ericc\anaconda3\lib\site-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in c:\users\ericc\anaconda3\lib\site-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\ericc\anaconda3\lib\site-packages (from google-generativeai) (2.43.0)
# Requirement already satisfied: protobuf in c:\users\ericc\anaconda3\lib\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\ericc\anaconda3\lib\site-packages (from google-generativeai) (2.12.3)
# Requirement already satisfied: tqdm in c:\users\ericc\anaconda3\lib\site-packages (from google-generativeai) (4.66.4)
# Requirement already satisfied: typing-extensions in c:\users\ericc\anaconda3\lib\site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\ericc\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\ericc\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\ericc\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\ericc\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ericc\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ericc\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\ericc\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\ericc\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\ericc\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic->google-generativeai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ericc\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\ericc\appdata\roaming\python\python312\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\ericc\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\ericc\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\ericc\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ericc\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ericc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ericc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ericc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ericc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.10.5)
# Requirement already satisfied: gephistreamer in c:\users\ericc\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: requests in c:\users\ericc\anaconda3\lib\site-packages (from gephistreamer) (2.32.5)
# Requirement already satisfied: ws4py in c:\users\ericc\anaconda3\lib\site-packages (from gephistreamer) (0.6.0)
# Requirement already satisfied: enum34 in c:\users\ericc\anaconda3\lib\site-packages (from gephistreamer) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ericc\anaconda3\lib\site-packages (from requests->gephistreamer) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ericc\anaconda3\lib\site-packages (from requests->gephistreamer) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ericc\anaconda3\lib\site-packages (from requests->gephistreamer) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ericc\anaconda3\lib\site-packages (from requests->gephistreamer) (2025.10.5)

# %% [markdown]
# ### Create a list of Web URL for data extraction

# %%
# list of top Tech leaders
url_list=[  
    'https://en.wikipedia.org/wiki/Elon_Musk',
    'https://en.wikipedia.org/wiki/Mark_Zuckerberg',
    'https://en.wikipedia.org/wiki/Bill_Gates',
    'https://en.wikipedia.org/wiki/Jeff_Bezos',
    'https://en.wikipedia.org/wiki/Steve_Jobs',
    'https://en.wikipedia.org/wiki/Sam_Altman',
    'https://en.wikipedia.org/wiki/Larry_Ellison',
    'https://en.wikipedia.org/wiki/Larry_Page',
    'https://en.wikipedia.org/wiki/Sundar_Pichai',
    'https://en.wikipedia.org/wiki/Satya_Nadella'  
]

# %% [markdown]
# ### Define function to clean data

# %%
# define a function to clean the extracted web URL data
import re #for regular expression 
 
def clean_text(text):
    # Remove HTML tags
    text = re.sub(r'<[^>]*?>', '', text)
    # Remove URLs
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)
    # Remove special characters
    text = re.sub(r'[^a-zA-Z0-9 ]', '', text)
# Replace multiple spaces with a single space
    text = re.sub(r'\s{2,}', ' ', text)
    # Trim leading and trailing whitespace
    text = text.strip()
    # Remove extra whitespace
    text = ' '.join(text.split())
    return text

# %% [markdown]
# ### Use Langchain framework to extract data

# %%
# extract the data from the URLs
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_community.document_loaders import WebBaseLoader
 
def extract_data_from_URL(url):
    loader=WebBaseLoader([url])
    data=loader.load().pop().page_content
    data=clean_text(data)
    documents=[Document(page_content=data)]
    # print(documents)
    splitter=RecursiveCharacterTextSplitter(chunk_size=3000,chunk_overlap=100)
    smaller_doc=splitter.split_documents(documents)
    print(len(smaller_doc))
    return smaller_doc
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# ### Use Gemini API and generate sample response

# %%
import google.generativeai as genai 
import os 
 
#system_instruction
system_prompt='''
Answer the question in JSON format and nothing else,Do not use code block formatting.
'''
# test connection for gemini 
genai.configure(api_key='AIzaSyBV53zeLNrslEn88SuDkWaJu1kUn1O_Ry4')
client = genai.GenerativeModel(model_name="gemini-2.5-flash", system_instruction=system_prompt)
response = client.generate_content("Write a story about how texas can become a tech hub in the future.")
print(response.text)
# Out:
# {
#   "title": "The Silicon Sagebrush: Texas's Tech Horizon",
#   "introduction": "In the year 2045, the scorching Texas sun still beat down, but its heat now fueled server farms and solar arrays, not just oil rigs. The scent of ozone mingled with the mesquite, a testament to a transformation few had dared to imagine just two decades prior. Texas, once defined by cattle, oil, and vast open spaces, had become a global titan of technology, its sprawling metropolises and revitalized small towns humming with innovation.",
#   "chapters": [
#     {
#       "title": "The Roots of Innovation",
#       "content": "It wasn't an overnight revolution. The seeds were always there. Texas had long been a crucible of big thinking—from NASA's lunar missions to the sprawling energy sector that demanded constant ingenuity. Its universities, like UT Austin, Texas A&M, and Rice, consistently produced top-tier engineering talent. Companies, seeing the lower cost of living and business-friendly environment, had already begun migrating south, a trickle that would soon become a flood. But the state needed more than just a welcome mat; it needed a blueprint. The challenge was to leverage these inherent strengths and overcome the perceived 'brain drain' to foster a self-sustaining ecosystem."
#     },
#     {
#       "title": "The Catalyst of Connection",
#       "content": "The first major pivot came in the late 2020s, with the 'Texas Connect' initiative. A multi-billion-dollar public-private partnership aimed to blanket the entire state, urban and rural, with ultra-high-speed fiber optics and 6G wireless infrastructure. Smart city projects, initially piloted in Austin and Dallas, expanded to Houston, San Antonio, and even smaller hubs like El Paso and Lubbock. Traffic flowed seamlessly through AI-optimized networks, energy grids balanced demand with renewable supply, and telehealth became as common as a stroll down Main Street. This ubiquitous connectivity didn't just link people; it linked ideas, creating a robust nervous system for a burgeoning tech ecosystem, breaking down geographical barriers that once siloed innovation."
#     },
#     {
#       "title": "Cultivating Talent",
#       "content": "Infrastructure alone wasn't enough. The state understood it needed minds. The 'Future Forward Education Act' revamped K-12 curricula, prioritizing coding, robotics, and critical thinking from elementary school. Community colleges transformed into specialized vocational tech institutes, churning out skilled technicians in AI maintenance, cybersecurity, and advanced manufacturing. Scholarships targeting underserved communities surged, ensuring that talent, not just privilege, dictated who entered the tech workforce. Texas also aggressively marketed its lifestyle and career opportunities, drawing a diverse influx of engineers, data scientists, and entrepreneurs from across the globe, attracted by the promise of impact and a life beyond cramped, overpriced coastal cities, fostering a true melting pot of innovation."
#     },
#     {
#       "title": "Fostering Ecosystems",
#       "content": "Capital followed talent. State-backed venture funds, paired with unprecedented tax incentives for early-stage tech companies, ignited a startup boom. Innovation districts sprouted in every major city, offering co-working spaces, mentorship programs, and direct access to university research. Austin cemented its place as a hub for AI and semiconductor design. Houston, leveraging its medical center, became a global leader in biotech and health tech. Dallas excelled in fintech and enterprise software, while San Antonio carved out a niche in cybersecurity and aerospace. Even the Panhandle, powered by vast wind farms, saw growth in cleantech and sustainable agriculture tech, proving that innovation wasn't confined to traditional urban centers but could thrive across diverse economic landscapes."
#     },
#     {
#       "title": "The Texas Spirit Reimagined",
#       "content": "The legendary Texas spirit—independent, resilient, and bold—found its modern expression. Tech founders weren't just building companies; they were building communities, investing in local schools, and mentoring the next generation. The 'can-do' attitude that once tamed the frontier now tackled complex global challenges, from sustainable energy solutions to advanced healthcare diagnostics. The old rivalries between cities transformed into friendly collaborations, each vying to contribute uniquely to the state's collective tech prowess. Texas remained fiercely individualistic, but its innovation was a symphony of diverse voices, echoing across the digital frontier."
#     }
#   ],
#   "conclusion": "By 2045, Texas wasn't just a tech hub; it was 'The Silicon Sagebrush,' a testament to how vision, collaboration, and a willingness to reinvent could transform an entire state. The hum of servers had replaced the clang of oil drills as the dominant sound of progress, and the Lone Star State shone brighter than ever, not just with its independent spirit, but with the brilliance of innovation.",
#   "epilogue": "A young girl in Marfa, far from the bustling cities, looked up from her augmented reality textbook, gazing at the real stars above. She was designing a new drone for sustainable ranching, connected to a global network of fellow innovators. The future of Texas, she knew, was limitless, built on a foundation of grit, vision, and untamed technological spirit."
# }

# %% [markdown]
# # Create system prompt for the LLM to understand context of the task

# %%
# create system prompt to extract data in JSON format as required
 
system=""" You are a network graph maker tasked with analyzing the relationships involving top leaders in the world. Your job is to process the provided context chunk 
and extract an ontology of terms that represent key entrepreneurs, their associated entities, and all kinds of relationships present in the context.
 
**Guidelines for Extraction:**
 
1. **Identify Key Entrepreneurs and Related Terms**:
   - Extract key entrepreneurs and related concepts such as:
     - Companies, organizations, or industries they are associated with.
     - Collaborators, partners, rivals, or competitors.
     - Key innovations, achievements, or milestones.
     - Locations, events, or time periods relevant to their actions.
 
2. **Identify Relationships**:
   - Extract all types of relationships between entrepreneurs and other entities (or between entities themselves).
   - Relationships can include:
     - Professional roles or associations.
     - Business partnerships, collaborations, or rivalries.
     - Innovations or contributions to industries.
     - Personal connections or influences.
     - Historical events or shared milestones.
 
3. **Define Relationships**:
   - Clearly specify the nature of each relationship in simple and concise terms.
   - Relationships should convey meaningful connections relevant to the context.
 
**Response Format**:
- Provide your output **strictly as a list of JSON objects**. No additional text, descriptions,tags or comments are allowed.
- Each object should include the following fields:
  - `"node_1"`: The first entity in the relationship (can be a person, organization, or concept).
  - `"node_2"`: The second entity in the relationship.
  - `"edge"`: A concise sentence describing the relationship between `node_1` and `node_2`.
 
**Example Output**:
[
   {
       "node_1": "Elon Musk",
       "node_2": "SpaceX",
       "edge": "Elon Musk founded SpaceX to revolutionize space exploration."
   },
   {
       "node_1": "Steve Jobs",
       "node_2": "Apple Inc.",
       "edge": "Steve Jobs co-founded Apple Inc., a leading tech company."
   },
   {
       "node_1": "Mark Zuckerberg",
       "node_2": "Sheryl Sandberg",
       "edge": "Sheryl Sandberg worked closely with Mark Zuckerberg as COO of Facebook."
   },
   {
       "node_1": "Jeff Bezos",
       "node_2": "Blue Origin",
       "edge": "Jeff Bezos founded Blue Origin to focus on space exploration."
   }
]
 
**Important Note**:
- Always respond exclusively in JSON format. Any deviation from the JSON structure or inclusion of additional text will not be accepted.
- Do not use code block formatting like ` ``` `.
- Output must be a valid JSON array of objects without any surrounding text.
 
Please provide the context containing information about entrepreneurs and their relationships for analysis.

"""

# %% [markdown]
# # Use LLM’s to extract data

# %%
from datetime import datetime
from itertools import cycle
 
results=[]
models = [
    'gemini-2.0-flash',
    'gemini-2.0-flash-lite',
    'gemini-1.5-pro',
    'gemini-1.5-flash',
    'gemini-1.5-flash-8b',
]
model_cycle = cycle(models)  # Create an infinite cycle of models
model_name = next(model_cycle)  # Start with the first model
start_time=datetime.now()
for url in url_list:
 
 
    
    smaller_doc=extract_data_from_URL(url)
    for doc in smaller_doc[:30]:
        try:
            client = genai.GenerativeModel(model_name=model_name, system_instruction=system,
                                           generation_config={"response_mime_type":'application/json'})
            chat_completion = client.generate_content(doc.page_content)
            # print(chat_completion.candidates[0].content.parts[0].text)
            results.append(chat_completion.candidates[0].content.parts[0].text)
        
        except Exception as e:
        #print('Exception',e)
            errordata=e.args[0]
            print(e.args)
    
            if 'exceeded' in errordata or 'exhausted' in errordata:
                print('Rate limit exceeded for model:', model_name)
                model_name = next(model_cycle)  # Switch to the next model
                print('Switching to model:', model_name)
                
end_time=datetime.now()
len(results)
print(f'extracted information in {end_time-start_time}')
# Out:
# 59
# 33
# 49
# ('You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 32.605889668s.',)
# Rate limit exceeded for model: gemini-2.0-flash
# Switching to model: gemini-2.0-flash-lite
# 44
# 47
# 15
# 22
# 27
# 12
# 11
# extracted information in 0:14:21.668382

# %% [markdown]
# # Save the result to JSON file

# %%
import json 
#print(results)
combined_nodes_and_edges=[]
for res in results:
    try:
        combined_nodes_and_edges.extend(json.loads(res)) #convert the string result from LLM to JSON 
    except Exception as e:
        print('buggy JSON object', e)
 
with open('Nodes_and_edges.json','w') as file:
    json.dump(combined_nodes_and_edges,file,indent=1)

# %% [markdown]
# # Send JSON data to Gephi

# %%
from gephistreamer import graph
from gephistreamer import streamer
# connect to gephi server
# create a stream 
stream = streamer.Streamer(streamer.GephiWS(hostname="localhost", port=8080, workspace="workspace1"))

# %% [markdown]
# # Load nodes and edges data from json to gephi

# %%
# load the nodes and edges from the json file
with open('Nodes_and_edges.json','r') as file:
    results=json.load(file)

# %%
# loop through the list of json result and send to Gephi
for res in results:
    try:        
        node_a = graph.Node(res['node_1'],custom_property=1)
        node_b = graph.Node(res['node_2'],custom_property=2)
        stream.add_node(node_a,node_b)
        edge_ab = graph.Edge(node_a,node_b,custom_property=res['edge'])
        stream.add_edge(edge_ab)
 
    except Exception as e:
        print('buggy JSON object', e,res)
